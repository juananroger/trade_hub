# %% [markdown]
# # 13. References
#
# - Anaconda, Inc. (n.d.). *Anaconda distribution (Download).* https://www.anaconda.com/download/
#
# - ATS Trading Solutions. (n.d.). *Built for purpose: Why every trend follower has a different mission.* https://atstradingsolutions.com/built-for-purpose-why-every-trend-follower-has-a-different-mission/
#
# - Carver, R. (2015). *Systematic trading: A unique new method for designing trading and investing systems.* Harriman House.
#
# - Carver, R. (2019). *Leveraged trading: A professional approach to trading FX, stocks on margin, CFDs, spread bets and futures for all traders.* Harriman House.
#
# - Clenow, A. (2013). *Following the trend: Diversified managed futures trading.* Wiley.
#
# - Clenow, A. (2015). *Stocks on the move: Beating the market with hedge fund momentum strategies.* Wiley.
#
# - Clenow, A. (2019). *Trading evolved: Anyone can build killer trading strategies in Python.* (Independently published).
#
# - CQF Institute. (2025). *JA25T10 Final Project—Tutorial IV* [Class handout].
#
# - Grinold, R. C., & Kahn, R. N. (1999). *Active portfolio management* (2nd ed.). McGraw–Hill.
#
# - Grinold, R. C., & Kahn, R. N. (2019). *Advances in active portfolio management: New developments in quantitative investing.* McGraw–Hill.
#
# - Hilpisch, Y. (2018). *Python for finance: Mastering data-driven finance* (2nd ed.). O’Reilly Media.
#
# - Hilpisch, Y. (2020). *Python for algorithmic trading: From idea to cloud deployment.* O’Reilly Media.
#
# - Interactive Brokers. (n.d.). *TWS API documentation.* https://interactivebrokers.github.io/tws-api/
#
# - Jansen, S. (n.d.). *zipline-reloaded* [Computer software]. GitHub. https://github.com/stefan-jansen/zipline-reloaded
#
# - Jansen, S. (2020). *Machine learning for algorithmic trading* (2nd ed.). Packt Publishing.
#
# - López de Prado, M. (2018). *Advances in financial machine learning.* Wiley.
#
# - Norgate Data. (n.d.). *Accessibility.* https://norgatedata.com/accessibility.php
#
# - Quantopian. (n.d.). *pyfolio* [Computer software]. GitHub. https://github.com/quantopian/pyfolio
#
# - Sortino, F. A. (2009). *The Sortino framework for constructing portfolios: Focusing on Desired Target Return™ to optimize upside potential relative to downside risk.* Elsevier.
#
# - vectorbt. (n.d.). *Resources.* https://vectorbt.dev/getting-started/resources/
#
# - Zakamulin, V. (2017). *Market timing with moving averages: The anatomy and performance of trading rules* (1st ed., New Developments in Quantitative Trading and Investment). Palgrave Macmillan.
#
# # 14. Software Verions Used
# All models and scripts were developed and tested on a Windows 10 system. The development environment was based on _conda_, using Python 3.12.3 and Conda version 25.5.1. The models were executed within a dedicated environment named zip35, which includes the following key package versions:

# %%
# !conda --version && python --version

# %%
# !pip list

# %% [markdown]
# Note: Due to legacy support for Zipline and compatibility with Norgate Data, Python 3.12.3 was selected. Users replicating the environment should ensure alignment with these versions to avoid runtime errors or deprecated dependencies. Likewise, users must have a subscription to the Norgatedata global futures package: https://norgatedata.com/futurespackage.php
